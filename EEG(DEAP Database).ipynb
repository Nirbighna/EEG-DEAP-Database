# %%
import pickle

nLabel, nTrial, nUser, nChannel, nTime  = 4, 40, 32, 40, 8064
no_of_users=32
def convertData():
    print("Program started"+"\n")
    fout_data = open("C:\\Users\\NIRBIGHNA\\Downloads\\features_raw.dat",'w')
    fout_labels0 = open("C:\\Users\\NIRBIGHNA\\Downloads\\labels_0.dat",'w')
    fout_labels1 = open("C:\\Users\\NIRBIGHNA\\Downloads\\labels_1.dat",'w')
    fout_labels2 = open("C:\\Users\\NIRBIGHNA\\Downloads\\labels_2.dat",'w')
    fout_labels3 = open("C:\\Users\\NIRBIGHNA\\Downloads\\labels_3.dat",'w')
    for i in range(no_of_users):  #nUser #4, 40, 32, 40, 8064 4 labels, 40 sample for each user, 32 such user, 40 electrode, 8064*40 features
        if(i%1 == 0):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        fname = "C:\\Users\\NIRBIGHNA\\Downloads\\data_preprocessed_python\\s"+str(name)+".dat"     
        f = open(fname, 'rb')                 #Read the file in Binary mode
        x = pickle.load(f, encoding='latin1')
        print(fname)                          
    	
        for tr in range(nTrial):
            if(tr%1 == 0):
                for dat in range(nTime):
                    if(dat%32 == 0):
                        for ch in range(nChannel):
                            fout_data.write(str(x['data'][tr][ch][dat]) + " ");
                fout_labels0.write(str(x['labels'][tr][0]) + "\n");
                fout_labels1.write(str(x['labels'][tr][1]) + "\n");
                fout_labels2.write(str(x['labels'][tr][2]) + "\n");
                fout_labels3.write(str(x['labels'][tr][3]) + "\n");
                fout_data.write("\n");
    fout_labels0.close()
    fout_labels1.close()
    fout_labels2.close()
    fout_labels3.close()
    fout_data.close()
    print("\n"+"Print Successful")
if __name__ == '__main__':
    convertData()
# Out:
# Program started
#
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s01.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s02.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s03.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s04.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s05.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s06.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s07.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s08.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s09.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s10.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s11.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s12.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s13.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s14.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s15.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s16.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s17.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s18.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s19.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s20.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s21.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s22.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s23.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s24.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s25.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s26.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s27.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s28.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s29.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s30.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s31.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s32.dat
#
# Print Successful

# %%
#Features sampled
import pickle

nLabel, nTrial, nUser, nChannel, nTime  = 4, 40, 32, 40, 8064  #10080/80=126*40=5040 features
no_of_users=32
def sampleFeatures():
    print("Program started"+"\n")
    fout_data = open('C:\\Users\\NIRBIGHNA\\Downloads\\features_sampled.dat','w')
    for i in range(no_of_users):   #nUser  #4, 40, 32, 40, 8064
        if(i%1 == 0):
            if i < 10:			
                name = '%0*d' % (2,i+1)
            else:
                name = i+1		
            fname = "C:\\Users\\NIRBIGHNA\\Downloads\\data_preprocessed_python\\s"+str(name)+".dat"
            x = pickle.load(open(fname, 'rb'), encoding='latin1')		
            print(fname)		
            for tr in range(nTrial):			
                if(tr%1 == 0):				
                    for dat in range(nTime):					
                        if(dat%32 == 0 ):						
                            for ch in range(nChannel):							
                                fout_data.write(str(ch+1) + " ");							
                                fout_data.write(str(x['data'][tr][ch][dat]) + " ");			
                fout_data.write("\n");
    fout_data.close()
    print('Completed')

if __name__ == '__main__':
    sampleFeatures()
# Out:
# Program started
#
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s01.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s02.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s03.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s04.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s05.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s06.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s07.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s08.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s09.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s10.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s11.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s12.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s13.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s14.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s15.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s16.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s17.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s18.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s19.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s20.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s21.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s22.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s23.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s24.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s25.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s26.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s27.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s28.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s29.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s30.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s31.dat
# C:\Users\NIRBIGHNA\Downloads\data_preprocessed_python\s32.dat
# Completed

# %%
def onehotencoding0():
    print("Program started"+"\n")
    fout_labels_class = open("C:\\Users\\NIRBIGHNA\\Downloads\\label_class_0.dat",'w')
    
    with open('C:\\Users\\NIRBIGHNA\\Downloads\\labels_0.dat','r') as f:
        for val in f:
            if float(val) > 4.5:
                fout_labels_class.write(str(1) + "\n");
            else:
                fout_labels_class.write(str(0) + "\n");
                
    print("Encoded label 0"+"\n")
if __name__ == '__main__':
    onehotencoding0()
# Out:
# Program started
#
# Encoded label 0

# %%
def onehotencoding1():
    print("Program started"+"\n")
    fout_labels_class = open("C:\\Users\\NIRBIGHNA\\Downloads\\label_class_1.dat",'w')
    
    with open('C:\\Users\\NIRBIGHNA\\Downloads\\labels_1.dat','r') as f:
        for val in f:
            if float(val) > 4.5:
                fout_labels_class.write(str(1) + "\n");
            else:
                fout_labels_class.write(str(0) + "\n");
                
    print("Encoded label 1"+"\n")
if __name__ == '__main__':
    onehotencoding1()
# Out:
# Program started
#
# Encoded label 1

# %%
def onehotencoding2():
    print("Program started"+"\n")
    fout_labels_class = open("C:\\Users\\NIRBIGHNA\\Downloads\\label_class_2.dat",'w')

    with open('C:\\Users\\NIRBIGHNA\\Downloads\\labels_1.dat','r') as f:
        for val in f:
            if float(val) > 4.5:
                fout_labels_class.write(str(1) + "\n");
            else:
                fout_labels_class.write(str(0) + "\n");
    print("Encoded label 2"+"\n")
if __name__ == '__main__':
    onehotencoding2()
# Out:
# Program started
#
# Encoded label 2

# %%
def onehotencoding3():
    print("Program started"+"\n")
    fout_labels_class = open("C:\\Users\\NIRBIGHNA\\Downloads\\label_class_3.dat",'w')
    
    with open('C:\\Users\\NIRBIGHNA\\Downloads\\labels_3.dat','r') as f:
        for val in f:
            if float(val) > 4.5:
                fout_labels_class.write(str(1) + "\n");
            else:
                fout_labels_class.write(str(0) + "\n");
                
    print("Encoded label 3"+"\n")
if __name__ == '__main__':
    onehotencoding3()
# Out:
# Program started
#
# Encoded label 3

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import time
import matplotlib.pyplot as plt 
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.simplefilter('ignore')

def cross_validate0():
    
    # Get Data
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_sampled.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_0.dat'
    
    X = np.genfromtxt(file_x, delimiter=' ')
    y = np.genfromtxt(file_y, delimiter=' ')
    
   
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42, shuffle=False)
    
     # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
     #principle component analysis
    from sklearn.decomposition import PCA
    pca = PCA(n_components=20)
    X_train = pca.fit_transform(X_train)
    X_test = pca.fit_transform(X_test)
    
   
    models = []
    models.append(('LR', LogisticRegression(random_state = 0)))
    models.append(('SVC', SVC(kernel = 'rbf', random_state = 0)))
     
    models.append(('KNN', KNeighborsClassifier(n_neighbors=5)))
    models.append(('DT', DecisionTreeClassifier(random_state = 0)))
    
    scoring = 'accuracy'
    
    # Cross Validate
    results = []
    names = []
    timer = []
    print('Model | Mean of CV | Std. Dev. of CV | Time')
    for name, model in models:
        start_time = time.time()
        kfold = model_selection.KFold(n_splits=5, random_state=0)
        cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
        t = (time.time() - start_time)
        timer.append(t)
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
        print(msg)
    
        
    models = []
    for i in range(1,41): 
        models.append(('KNN', KNeighborsClassifier(n_neighbors=i)))
        results = []
        names = []
        timer = []
        cv_knn = []
        
        print('Model  | Mean of CV | Std. Dev. of CV | Time',i)
        for name, model in models:
            start_time = time.time()
            kfold = model_selection.KFold(n_splits=4, random_state=42)
            cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
            t = (time.time() - start_time)
            timer.append(t)
            results.append(cv_results)
            names.append(name)
            msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
                
            cv_knn.append(cv_results.mean())
        print(msg)
        
    print('\nmaximum accuracy for valence is',max(cv_knn))

    
    plt.figure(figsize=(12, 6))  
    plt.plot(range(1, 41), cv_knn, color='red', linestyle='dashed', marker='o',  
             markerfacecolor='blue', markersize=10)
    plt.title('mean cv_results of  K Value for Valence')  
    plt.xlabel('K Value')  
    plt.ylabel('Mean cv_result')  
    
        
if __name__ == '__main__':
    cross_validate0()
# Out:
# Model | Mean of CV | Std. Dev. of CV | Time
# LR: 0.620515 (0.044150) 0.060348 s
# SVC: 0.623898 (0.046827) 0.121152 s
# KNN: 0.565909 (0.033241) 0.070403 s
# DT: 0.531254 (0.025385) 0.058385 s
# Model  | Mean of CV | Std. Dev. of CV | Time 1
# KNN: 0.531250 (0.005468) 0.042370 s
# Model  | Mean of CV | Std. Dev. of CV | Time 2
# KNN: 0.463170 (0.044907) 0.050523 s
# Model  | Mean of CV | Std. Dev. of CV | Time 3
# KNN: 0.555804 (0.014974) 0.050447 s
# Model  | Mean of CV | Std. Dev. of CV | Time 4
# KNN: 0.508929 (0.021176) 0.042468 s
# Model  | Mean of CV | Std. Dev. of CV | Time 5
# KNN: 0.561384 (0.039222) 0.050410 s
# Model  | Mean of CV | Std. Dev. of CV | Time 6
# KNN: 0.516741 (0.023278) 0.042480 s
# Model  | Mean of CV | Std. Dev. of CV | Time 7
# KNN: 0.574777 (0.045349) 0.050349 s
# Model  | Mean of CV | Std. Dev. of CV | Time 8
# KNN: 0.554688 (0.021264) 0.060396 s
# Model  | Mean of CV | Std. Dev. of CV | Time 9
# KNN: 0.578125 (0.061899) 0.050493 s
# Model  | Mean of CV | Std. Dev. of CV | Time 10
# KNN: 0.558036 (0.040794) 0.048506 s
# Model  | Mean of CV | Std. Dev. of CV | Time 11
# KNN: 0.571429 (0.046501) 0.048496 s
# Model  | Mean of CV | Std. Dev. of CV | Time 12
# KNN: 0.552455 (0.030340) 0.050317 s
# Model  | Mean of CV | Std. Dev. of CV | Time 13
# KNN: 0.563616 (0.035487) 0.050515 s
# Model  | Mean of CV | Std. Dev. of CV | Time 14
# KNN: 0.552455 (0.030175) 0.050542 s
# Model  | Mean of CV | Std. Dev. of CV | Time 15
# KNN: 0.575893 (0.041037) 0.042434 s
# Model  | Mean of CV | Std. Dev. of CV | Time 16
# KNN: 0.564732 (0.038597) 0.050553 s
# Model  | Mean of CV | Std. Dev. of CV | Time 17
# KNN: 0.572545 (0.044461) 0.052858 s
# Model  | Mean of CV | Std. Dev. of CV | Time 18
# KNN: 0.561384 (0.042513) 0.054857 s
# Model  | Mean of CV | Std. Dev. of CV | Time 19
# KNN: 0.587054 (0.044699) 0.052859 s
# Model  | Mean of CV | Std. Dev. of CV | Time 20
# KNN: 0.581473 (0.044907) 0.052866 s
# Model  | Mean of CV | Std. Dev. of CV | Time 21
# KNN: 0.594866 (0.040349) 0.054849 s
# Model  | Mean of CV | Std. Dev. of CV | Time 22
# KNN: 0.581473 (0.042160) 0.050864 s
# Model  | Mean of CV | Std. Dev. of CV | Time 23
# KNN: 0.584821 (0.049107) 0.051861 s
# Model  | Mean of CV | Std. Dev. of CV | Time 24
# KNN: 0.578125 (0.049360) 0.053864 s
# Model  | Mean of CV | Std. Dev. of CV | Time 25
# KNN: 0.588170 (0.050248) 0.054852 s
# Model  | Mean of CV | Std. Dev. of CV | Time 26
# KNN: 0.575893 (0.049612) 0.054856 s
# Model  | Mean of CV | Std. Dev. of CV | Time 27
# KNN: 0.593750 (0.050211) 0.054833 s
# Model  | Mean of CV | Std. Dev. of CV | Time 28
# KNN: 0.588170 (0.047913) 0.046655 s
# Model  | Mean of CV | Std. Dev. of CV | Time 29
# KNN: 0.600446 (0.055625) 0.053930 s
# Model  | Mean of CV | Std. Dev. of CV | Time 30
# KNN: 0.588170 (0.055344) 0.054846 s
# Model  | Mean of CV | Std. Dev. of CV | Time 31
# KNN: 0.598214 (0.050606) 0.054852 s
# Model  | Mean of CV | Std. Dev. of CV | Time 32
# KNN: 0.597098 (0.056854) 0.055840 s
# Model  | Mean of CV | Std. Dev. of CV | Time 33
# KNN: 0.603795 (0.047180) 0.053857 s
# Model  | Mean of CV | Std. Dev. of CV | Time 34
# KNN: 0.597098 (0.049044) 0.054852 s
# Model  | Mean of CV | Std. Dev. of CV | Time 35
# KNN: 0.610491 (0.052098) 0.055820 s
# Model  | Mean of CV | Std. Dev. of CV | Time 36
# KNN: 0.606027 (0.044124) 0.055852 s
# Model  | Mean of CV | Std. Dev. of CV | Time 37
# KNN: 0.604911 (0.042878) 0.054846 s
# Model  | Mean of CV | Std. Dev. of CV | Time 38
# KNN: 0.602679 (0.044531) 0.055855 s
# Model  | Mean of CV | Std. Dev. of CV | Time 39
# KNN: 0.616071 (0.050606) 0.052587 s
# Model  | Mean of CV | Std. Dev. of CV | Time 40
# KNN: 0.604911 (0.046448) 0.059109 s
#
# maximum accuracy for valence is 0.6160714285714286

# %%
import numpy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import time
import matplotlib.pyplot as plt 
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.simplefilter('ignore')

def cross_validate1():
    
    # Get Data
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_sampled.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_1.dat'
    
    X = numpy.genfromtxt(file_x, delimiter=' ')
    y = numpy.genfromtxt(file_y, delimiter=' ')
    
    X = StandardScaler().fit_transform(X)
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
    
     #principle component analysis
    from sklearn.decomposition import PCA
    pca = PCA(n_components=20)
    X_train = pca.fit_transform(X_train)
    X_test = pca.fit_transform(X_test)
   
    models = []
    models.append(('LR', LogisticRegression(random_state = 42)))
    models.append(('SVC', SVC(kernel = 'rbf', random_state = 42)))
    models.append(('KNN', KNeighborsClassifier(n_neighbors=5)))
    models.append(('DT', DecisionTreeClassifier(random_state = 42)))
    
    scoring = 'accuracy'
    
    # Cross Validate
    results = []
    names = []
    timer = []
    print('Model | Mean of CV | Std. Dev. of CV | Time')
    for name, model in models:
        start_time = time.time()
        kfold = model_selection.KFold(n_splits=5, random_state=42)
        cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
        t = (time.time() - start_time)
        timer.append(t)
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
        print(msg)
    
    models = []
    for i in range(1,41): 
        models.append(('KNN', KNeighborsClassifier(n_neighbors=i)))
        results = []
        names = []
        timer = []
        cv_knn = []
        
        print('Model  | Mean of CV | Std. Dev. of CV | Time',i)
        for name, model in models:
            start_time = time.time()
            kfold = model_selection.KFold(n_splits=5, random_state=42)
            cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
            t = (time.time() - start_time)
            timer.append(t)
            results.append(cv_results)
            names.append(name)
            msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
                
            cv_knn.append(cv_results.mean())
        print(msg)
    print('\nmaximum accuracy for arousal  is',max(cv_knn))
    plt.figure(figsize=(12, 6))  
    plt.plot(range(1,41), cv_knn, color='red', linestyle='dashed', marker='o',  
             markerfacecolor='blue', markersize=10)
    plt.title('mean cv_results of  K Value for Arousal')  
    plt.xlabel('K Value')  
    plt.ylabel('Mean cv_result')  
        
if __name__ == '__main__':
    cross_validate1()
# Out:
# Model | Mean of CV | Std. Dev. of CV | Time
# LR: 0.628349 (0.033240) 0.045042 s
# SVC: 0.639503 (0.031377) 0.123669 s
# KNN: 0.600441 (0.016908) 0.060839 s
# DT: 0.532390 (0.030485) 0.057471 s
# Model  | Mean of CV | Std. Dev. of CV | Time 1
# KNN: 0.584848 (0.038326) 0.047902 s
# Model  | Mean of CV | Std. Dev. of CV | Time 2
# KNN: 0.517827 (0.030535) 0.051857 s
# Model  | Mean of CV | Std. Dev. of CV | Time 3
# KNN: 0.572570 (0.015683) 0.053881 s
# Model  | Mean of CV | Std. Dev. of CV | Time 4
# KNN: 0.525667 (0.016226) 0.055858 s
# Model  | Mean of CV | Std. Dev. of CV | Time 5
# KNN: 0.600441 (0.016908) 0.055850 s
# Model  | Mean of CV | Std. Dev. of CV | Time 6
# KNN: 0.566983 (0.012813) 0.055851 s
# Model  | Mean of CV | Std. Dev. of CV | Time 7
# KNN: 0.612706 (0.035253) 0.054885 s
# Model  | Mean of CV | Std. Dev. of CV | Time 8
# KNN: 0.578125 (0.025602) 0.055843 s
# Model  | Mean of CV | Std. Dev. of CV | Time 9
# KNN: 0.620528 (0.027008) 0.056844 s
# Model  | Mean of CV | Std. Dev. of CV | Time 10
# KNN: 0.597083 (0.013369) 0.055851 s
# Model  | Mean of CV | Std. Dev. of CV | Time 11
# KNN: 0.608268 (0.013567) 0.056846 s
# Model  | Mean of CV | Std. Dev. of CV | Time 12
# KNN: 0.594867 (0.007498) 0.056852 s
# Model  | Mean of CV | Std. Dev. of CV | Time 13
# KNN: 0.599342 (0.009717) 0.057841 s
# Model  | Mean of CV | Std. Dev. of CV | Time 14
# KNN: 0.587070 (0.013588) 0.056848 s
# Model  | Mean of CV | Std. Dev. of CV | Time 15
# KNN: 0.601589 (0.014013) 0.060870 s
# Model  | Mean of CV | Std. Dev. of CV | Time 16
# KNN: 0.597095 (0.006652) 0.057842 s
# Model  | Mean of CV | Std. Dev. of CV | Time 17
# KNN: 0.600453 (0.016609) 0.052953 s
# Model  | Mean of CV | Std. Dev. of CV | Time 18
# KNN: 0.593755 (0.021485) 0.050484 s
# Model  | Mean of CV | Std. Dev. of CV | Time 19
# KNN: 0.607145 (0.028579) 0.060610 s
# Model  | Mean of CV | Std. Dev. of CV | Time 20
# KNN: 0.595990 (0.027371) 0.050559 s
# Model  | Mean of CV | Std. Dev. of CV | Time 21
# KNN: 0.606021 (0.036870) 0.050591 s
# Model  | Mean of CV | Std. Dev. of CV | Time 22
# KNN: 0.600453 (0.030209) 0.060576 s
# Model  | Mean of CV | Std. Dev. of CV | Time 23
# KNN: 0.622775 (0.032019) 0.050575 s
# Model  | Mean of CV | Std. Dev. of CV | Time 24
# KNN: 0.609373 (0.028058) 0.052597 s
# Model  | Mean of CV | Std. Dev. of CV | Time 25
# KNN: 0.629448 (0.025357) 0.050531 s
# Model  | Mean of CV | Std. Dev. of CV | Time 26
# KNN: 0.625003 (0.032025) 0.060606 s
# Model  | Mean of CV | Std. Dev. of CV | Time 27
# KNN: 0.629454 (0.031634) 0.060620 s
# Model  | Mean of CV | Std. Dev. of CV | Time 28
# KNN: 0.618312 (0.036039) 0.060677 s
# Model  | Mean of CV | Std. Dev. of CV | Time 29
# KNN: 0.621651 (0.026530) 0.060571 s
# Model  | Mean of CV | Std. Dev. of CV | Time 30
# KNN: 0.621670 (0.031245) 0.060638 s
# Model  | Mean of CV | Std. Dev. of CV | Time 31
# KNN: 0.622781 (0.027984) 0.060628 s
# Model  | Mean of CV | Std. Dev. of CV | Time 32
# KNN: 0.621651 (0.021603) 0.052593 s
# Model  | Mean of CV | Std. Dev. of CV | Time 33
# KNN: 0.617169 (0.022515) 0.058585 s
# Model  | Mean of CV | Std. Dev. of CV | Time 34
# KNN: 0.620528 (0.026541) 0.060586 s
# Model  | Mean of CV | Std. Dev. of CV | Time 35
# KNN: 0.622756 (0.026732) 0.060654 s
# Model  | Mean of CV | Std. Dev. of CV | Time 36
# KNN: 0.618281 (0.028895) 0.062832 s
# Model  | Mean of CV | Std. Dev. of CV | Time 37
# KNN: 0.627219 (0.021522) 0.060583 s
# Model  | Mean of CV | Std. Dev. of CV | Time 38
# KNN: 0.626108 (0.015164) 0.061334 s
# Model  | Mean of CV | Std. Dev. of CV | Time 39
# KNN: 0.623873 (0.017370) 0.060623 s
# Model  | Mean of CV | Std. Dev. of CV | Time 40
# KNN: 0.624984 (0.014673) 0.060621 s
#
# maximum accuracy for arousal  is 0.629453755431409

# %%
import numpy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import time
import matplotlib.pyplot as plt 
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.simplefilter('ignore')

def cross_validate2():
    
    # Get Data
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_sampled.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_2.dat'
    
    X = numpy.genfromtxt(file_x, delimiter=' ')
    y = numpy.genfromtxt(file_y, delimiter=' ')
    
    X = StandardScaler().fit_transform(X)
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
   
    
     #principle component analysis
    from sklearn.decomposition import PCA
    pca = PCA(n_components=20)
    X_train = pca.fit_transform(X_train)
    X_test = pca.fit_transform(X_test)
    
    
    	
    models = []
    models.append(('LR', LogisticRegression(random_state = 42)))
    models.append(('SVC', SVC(kernel = 'rbf', random_state = 42)))
    models.append(('KNN', KNeighborsClassifier(n_neighbors=5)))
    models.append(('DT', DecisionTreeClassifier(random_state =42)))
    
    scoring = 'accuracy'
    
    # Cross Validate
    results = []
    names = []
    timer = []
    print('Model | Mean of CV | Std. Dev. of CV | Time')
    for name, model in models:
        start_time = time.time()
        kfold = model_selection.KFold(n_splits=5, random_state=42)
        cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
        t = (time.time() - start_time)
        timer.append(t)
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
        print(msg)
    
        models = []
    for i in range(1,41): 
        models.append(('KNN', KNeighborsClassifier(n_neighbors=i)))
        results = []
        names = []
        timer = []
        cv_knn = []
        
        print('Model  | Mean of CV | Std. Dev. of CV | Time',i)
        for name, model in models:
            start_time = time.time()
            kfold = model_selection.KFold(n_splits=5, random_state=42)
            cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
            t = (time.time() - start_time)
            timer.append(t)
            results.append(cv_results)
            names.append(name)
            msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
                
            cv_knn.append(cv_results.mean())
        print(msg)
    print('\nmaximum accuracy for dominance is',max(cv_knn))
    plt.figure(figsize=(12, 6))  
    plt.plot(range(1,41), cv_knn, color='red', linestyle='dashed', marker='o',  
             markerfacecolor='blue', markersize=10)
    plt.title('mean cv_results of  K Value for dominance')  
    plt.xlabel('K Value')  
    plt.ylabel('Mean cv_result')  
        
if __name__ == '__main__':
    cross_validate2()
# Out:
# Model | Mean of CV | Std. Dev. of CV | Time
# LR: 0.627232 (0.034143) 0.062864 s
# SVC: 0.639503 (0.031377) 0.184474 s
# KNN: 0.604910 (0.008198) 0.074802 s
# DT: 0.532334 (0.031122) 0.063827 s
# Model  | Mean of CV | Std. Dev. of CV | Time 1
# KNN: 0.582607 (0.038719) 0.062834 s
# Model  | Mean of CV | Std. Dev. of CV | Time 2
# KNN: 0.496642 (0.041218) 0.068779 s
# Model  | Mean of CV | Std. Dev. of CV | Time 3
# KNN: 0.564749 (0.016471) 0.094746 s
# Model  | Mean of CV | Std. Dev. of CV | Time 4
# KNN: 0.511161 (0.010301) 0.065826 s
# Model  | Mean of CV | Std. Dev. of CV | Time 5
# KNN: 0.604910 (0.008198) 0.114724 s
# Model  | Mean of CV | Std. Dev. of CV | Time 6
# KNN: 0.565866 (0.011196) 0.079818 s
# Model  | Mean of CV | Std. Dev. of CV | Time 7
# KNN: 0.606021 (0.017979) 0.082779 s
# Model  | Mean of CV | Std. Dev. of CV | Time 8
# KNN: 0.581484 (0.018433) 0.061902 s
# Model  | Mean of CV | Std. Dev. of CV | Time 9
# KNN: 0.604929 (0.017364) 0.093743 s
# Model  | Mean of CV | Std. Dev. of CV | Time 10
# KNN: 0.590428 (0.013538) 0.077828 s
# Model  | Mean of CV | Std. Dev. of CV | Time 11
# KNN: 0.603780 (0.007761) 0.057467 s
# Model  | Mean of CV | Std. Dev. of CV | Time 12
# KNN: 0.585934 (0.005642) 0.056570 s
# Model  | Mean of CV | Std. Dev. of CV | Time 13
# KNN: 0.603780 (0.010497) 0.060832 s
# Model  | Mean of CV | Std. Dev. of CV | Time 14
# KNN: 0.592638 (0.018581) 0.067602 s
# Model  | Mean of CV | Std. Dev. of CV | Time 15
# KNN: 0.602706 (0.014757) 0.060806 s
# Model  | Mean of CV | Std. Dev. of CV | Time 16
# KNN: 0.594873 (0.010051) 0.069852 s
# Model  | Mean of CV | Std. Dev. of CV | Time 17
# KNN: 0.602700 (0.018990) 0.067810 s
# Model  | Mean of CV | Std. Dev. of CV | Time 18
# KNN: 0.597138 (0.023032) 0.057846 s
# Model  | Mean of CV | Std. Dev. of CV | Time 19
# KNN: 0.604941 (0.028981) 0.063836 s
# Model  | Mean of CV | Std. Dev. of CV | Time 20
# KNN: 0.603811 (0.020854) 0.050370 s
# Model  | Mean of CV | Std. Dev. of CV | Time 21
# KNN: 0.618318 (0.028406) 0.052519 s
# Model  | Mean of CV | Std. Dev. of CV | Time 22
# KNN: 0.610521 (0.027209) 0.062832 s
# Model  | Mean of CV | Std. Dev. of CV | Time 23
# KNN: 0.628349 (0.025110) 0.053248 s
# Model  | Mean of CV | Std. Dev. of CV | Time 24
# KNN: 0.610490 (0.025572) 0.059847 s
# Model  | Mean of CV | Std. Dev. of CV | Time 25
# KNN: 0.618312 (0.026213) 0.061834 s
# Model  | Mean of CV | Std. Dev. of CV | Time 26
# KNN: 0.614966 (0.028764) 0.061379 s
# Model  | Mean of CV | Std. Dev. of CV | Time 27
# KNN: 0.623880 (0.033483) 0.061309 s
# Model  | Mean of CV | Std. Dev. of CV | Time 28
# KNN: 0.618305 (0.036622) 0.062196 s
# Model  | Mean of CV | Std. Dev. of CV | Time 29
# KNN: 0.617169 (0.035440) 0.060770 s
# Model  | Mean of CV | Std. Dev. of CV | Time 30
# KNN: 0.612725 (0.030070) 0.059449 s
# Model  | Mean of CV | Std. Dev. of CV | Time 31
# KNN: 0.621651 (0.032456) 0.060751 s
# Model  | Mean of CV | Std. Dev. of CV | Time 32
# KNN: 0.612731 (0.021789) 0.064827 s
# Model  | Mean of CV | Std. Dev. of CV | Time 33
# KNN: 0.621639 (0.029374) 0.061834 s
# Model  | Mean of CV | Std. Dev. of CV | Time 34
# KNN: 0.618281 (0.030163) 0.060619 s
# Model  | Mean of CV | Std. Dev. of CV | Time 35
# KNN: 0.620515 (0.027626) 0.061833 s
# Model  | Mean of CV | Std. Dev. of CV | Time 36
# KNN: 0.614935 (0.026240) 0.061463 s
# Model  | Mean of CV | Std. Dev. of CV | Time 37
# KNN: 0.620528 (0.025826) 0.060837 s
# Model  | Mean of CV | Std. Dev. of CV | Time 38
# KNN: 0.620528 (0.018839) 0.061835 s
# Model  | Mean of CV | Std. Dev. of CV | Time 39
# KNN: 0.623873 (0.025026) 0.064827 s
# Model  | Mean of CV | Std. Dev. of CV | Time 40
# KNN: 0.622756 (0.019430) 0.063824 s
#
# maximum accuracy for dominance is 0.628348851644941

# %%
import numpy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import time
import matplotlib.pyplot as plt 
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.simplefilter('ignore')

def cross_validate3():
    
    # Get Data
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_sampled.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_3.dat'
    
    X = numpy.genfromtxt(file_x, delimiter=' ')
    y = numpy.genfromtxt(file_y, delimiter=' ')
    
   #X = StandardScaler().fit_transform(X)
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
     # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    #principle component analysis
    from sklearn.decomposition import PCA
    pca = PCA(n_components=20)
    X_train = pca.fit_transform(X_train)
    X_test = pca.fit_transform(X_test)
    
   
    	
    models = []
    models.append(('LR', LogisticRegression(random_state = 42)))
    models.append(('SVC', SVC(kernel = 'rbf', random_state = 42)))
    models.append(('KNN', KNeighborsClassifier(n_neighbors=5)))
    models.append(('DT', DecisionTreeClassifier(random_state = 42)))
    
    scoring = 'accuracy'
    
    # Cross Validate
    results = []
    names = []
    timer = []
    print('Model | Mean of CV | Std. Dev. of CV | Time')
    for name, model in models:
        start_time = time.time()
        kfold = model_selection.KFold(n_splits=5, random_state=42)
        cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
        t = (time.time() - start_time)
        timer.append(t)
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
        print(msg)
    
    models = []
    for i in range(1,41): 
        models.append(('KNN', KNeighborsClassifier(n_neighbors=i)))
        results = []
        names = []
        timer = []
        cv_knn = []
        
        print('Model  | Mean of CV | Std. Dev. of CV | Time',i)
        for name, model in models:
            start_time = time.time()
            kfold = model_selection.KFold(n_splits=5, random_state=42)
            cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
            t = (time.time() - start_time)
            timer.append(t)
            results.append(cv_results)
            names.append(name)
            msg = "%s: %f (%f) %f s" % (name, cv_results.mean(), cv_results.std(), t)
                
            cv_knn.append(cv_results.mean())
        print(msg)
    print('\nmaximum accuracy for liking is',max(cv_knn))
    plt.figure(figsize=(12, 6))  
    plt.plot(range(1, 41), cv_knn, color='red', linestyle='dashed', marker='o',  
             markerfacecolor='blue', markersize=10)
    plt.title('mean cv_results of  K Value for liking')  
    plt.xlabel('K Value')  
    plt.ylabel('Mean cv_result')  
        
if __name__ == '__main__':
    cross_validate3()
# Out:
# Model | Mean of CV | Std. Dev. of CV | Time
# LR: 0.694221 (0.058065) 0.042887 s
# SVC: 0.704246 (0.058883) 0.117717 s
# KNN: 0.645109 (0.041112) 0.075763 s
# DT: 0.597163 (0.043919) 0.056848 s
# Model  | Mean of CV | Std. Dev. of CV | Time 1
# KNN: 0.587083 (0.032744) 0.048869 s
# Model  | Mean of CV | Std. Dev. of CV | Time 2
# KNN: 0.493284 (0.025199) 0.057846 s
# Model  | Mean of CV | Std. Dev. of CV | Time 3
# KNN: 0.620571 (0.033631) 0.052859 s
# Model  | Mean of CV | Std. Dev. of CV | Time 4
# KNN: 0.580366 (0.029286) 0.053856 s
# Model  | Mean of CV | Std. Dev. of CV | Time 5
# KNN: 0.645109 (0.041112) 0.055851 s
# Model  | Mean of CV | Std. Dev. of CV | Time 6
# KNN: 0.608268 (0.023100) 0.054853 s
# Model  | Mean of CV | Std. Dev. of CV | Time 7
# KNN: 0.659640 (0.038448) 0.054853 s
# Model  | Mean of CV | Std. Dev. of CV | Time 8
# KNN: 0.640689 (0.045831) 0.055851 s
# Model  | Mean of CV | Std. Dev. of CV | Time 9
# KNN: 0.669677 (0.052449) 0.056847 s
# Model  | Mean of CV | Std. Dev. of CV | Time 10
# KNN: 0.650708 (0.038899) 0.054854 s
# Model  | Mean of CV | Std. Dev. of CV | Time 11
# KNN: 0.671924 (0.056245) 0.055851 s
# Model  | Mean of CV | Std. Dev. of CV | Time 12
# KNN: 0.659646 (0.049842) 0.055851 s
# Model  | Mean of CV | Std. Dev. of CV | Time 13
# KNN: 0.679739 (0.064525) 0.055851 s
# Model  | Mean of CV | Std. Dev. of CV | Time 14
# KNN: 0.669690 (0.059915) 0.056848 s
# Model  | Mean of CV | Std. Dev. of CV | Time 15
# KNN: 0.687529 (0.060722) 0.066821 s
# Model  | Mean of CV | Std. Dev. of CV | Time 16
# KNN: 0.675270 (0.061462) 0.066828 s
# Model  | Mean of CV | Std. Dev. of CV | Time 17
# KNN: 0.687523 (0.061778) 0.060725 s
# Model  | Mean of CV | Std. Dev. of CV | Time 18
# KNN: 0.681962 (0.061459) 0.060867 s
# Model  | Mean of CV | Std. Dev. of CV | Time 19
# KNN: 0.689758 (0.054185) 0.059837 s
# Model  | Mean of CV | Std. Dev. of CV | Time 20
# KNN: 0.681962 (0.059916) 0.062796 s
# Model  | Mean of CV | Std. Dev. of CV | Time 21
# KNN: 0.695332 (0.056813) 0.061873 s
# Model  | Mean of CV | Std. Dev. of CV | Time 22
# KNN: 0.694221 (0.053709) 0.060838 s
# Model  | Mean of CV | Std. Dev. of CV | Time 23
# KNN: 0.696437 (0.056327) 0.061835 s
# Model  | Mean of CV | Std. Dev. of CV | Time 24
# KNN: 0.690857 (0.047815) 0.060841 s
# Model  | Mean of CV | Std. Dev. of CV | Time 25
# KNN: 0.700906 (0.054152) 0.061834 s
# Model  | Mean of CV | Std. Dev. of CV | Time 26
# KNN: 0.693091 (0.051977) 0.061833 s
# Model  | Mean of CV | Std. Dev. of CV | Time 27
# KNN: 0.698672 (0.056578) 0.059838 s
# Model  | Mean of CV | Std. Dev. of CV | Time 28
# KNN: 0.691980 (0.060947) 0.059840 s
# Model  | Mean of CV | Std. Dev. of CV | Time 29
# KNN: 0.699795 (0.061140) 0.062329 s
# Model  | Mean of CV | Std. Dev. of CV | Time 30
# KNN: 0.698684 (0.063966) 0.059838 s
# Model  | Mean of CV | Std. Dev. of CV | Time 31
# KNN: 0.703135 (0.058899) 0.063942 s
# Model  | Mean of CV | Std. Dev. of CV | Time 32
# KNN: 0.700900 (0.058934) 0.062869 s
# Model  | Mean of CV | Std. Dev. of CV | Time 33
# KNN: 0.700900 (0.055553) 0.052698 s
# Model  | Mean of CV | Std. Dev. of CV | Time 34
# KNN: 0.698678 (0.055988) 0.063855 s
# Model  | Mean of CV | Std. Dev. of CV | Time 35
# KNN: 0.700906 (0.057397) 0.064832 s
# Model  | Mean of CV | Std. Dev. of CV | Time 36
# KNN: 0.699789 (0.054823) 0.064826 s
# Model  | Mean of CV | Std. Dev. of CV | Time 37
# KNN: 0.700906 (0.054036) 0.060584 s
# Model  | Mean of CV | Std. Dev. of CV | Time 38
# KNN: 0.698672 (0.054097) 0.060599 s
# Model  | Mean of CV | Std. Dev. of CV | Time 39
# KNN: 0.699789 (0.055727) 0.060655 s
# Model  | Mean of CV | Std. Dev. of CV | Time 40
# KNN: 0.700906 (0.057397) 0.060582 s
#
# maximum accuracy for liking is 0.7031346989447548

# %%
import numpy
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pandas as pd

 
def svm_classifier_pca():
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_raw.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_0.dat'
    print("LABEL 0 - Valence \n ")
    
    X = numpy.genfromtxt(file_x, delimiter=' ')
    y = numpy.genfromtxt(file_y, delimiter=' ')
    print("Split the data into training/testing sets \n")
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test_0 = train_test_split(X, y, test_size=0.33, random_state=42)
     
    
    print("Feature Scaling \n")
    
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    print("Applying PCA to select features \n")
    
    # PCA to select features
    pca = PCA(n_components=20, svd_solver='full')
    pca.fit(X)
    X = pca.transform(X)
    #explained_variance=pca.explained_variance_ratio_
    
    print("Applying SVM classifier \n")
    # SVM Classifier
    clf = SVC()
    clf.fit(X_train, y_train)
    y_predict_0 = clf.predict(X_test)
    cm = confusion_matrix(y_test_0, y_predict_0)
    print(cm)
    print("Accuracy score of Valence SVM-PCA")
    print(accuracy_score(y_test_0, y_predict_0)*100)
    
    #######################################################################
    
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_raw.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_1.dat'
    print("LABEL 1 - Arousal \n ")
    
    X = numpy.genfromtxt(file_x, delimiter=' ')
    y = numpy.genfromtxt(file_y, delimiter=' ')
    print("Split the data into training/testing sets \n")
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test_0 = train_test_split(X, y, test_size=0.33, random_state=42)
     
    
    print("Feature Scaling \n")
    
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    print("Applying PCA to select features \n")
    
    # PCA to select features
    pca = PCA(n_components=20, svd_solver='full')
    pca.fit(X)
    X = pca.transform(X)
    #explained_variance=pca.explained_variance_ratio_
    
    print("Applying SVM classifier \n")
    # SVM Classifier
    clf = SVC()
    clf.fit(X_train, y_train)
    y_predict_0 = clf.predict(X_test)
    cm = confusion_matrix(y_test_0, y_predict_0)
    print(cm)
    print("Accuracy score of Arousal SVM-PCA")
    print(accuracy_score(y_test_0, y_predict_0)*100)
    
    #######################################################################
    
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_raw.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_2.dat'
    print("LABEL 2 - Dominance \n ")
    
    X = numpy.genfromtxt(file_x, delimiter=' ')
    y = numpy.genfromtxt(file_y, delimiter=' ')
    print("Split the data into training/testing sets \n")
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test_0 = train_test_split(X, y, test_size=0.33, random_state=42)
     
    
    print("Feature Scaling \n")
    
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    print("Applying PCA to select features \n")
    
    # PCA to select features
    pca = PCA(n_components=20, svd_solver='full')
    pca.fit(X)
    X = pca.transform(X)
    #explained_variance=pca.explained_variance_ratio_
    
    print("Applying SVM classifier \n")
    # SVM Classifier
    clf = SVC()
    clf.fit(X_train, y_train)
    y_predict_0 = clf.predict(X_test)
    cm = confusion_matrix(y_test_0, y_predict_0)
    print(cm)
    print("Accuracy score of Dominance SVM-PCA")
    print(accuracy_score(y_test_0, y_predict_0)*100)
    
    #######################################################################
    
    
    file_x = 'C:\\Users\\NIRBIGHNA\\Downloads\\features_raw.dat'
    file_y = 'C:\\Users\\NIRBIGHNA\\Downloads\\label_class_3.dat'
    print("LABEL 3 - Liking \n ")
    
    X = numpy.genfromtxt(file_x, delimiter=' ')
    y = numpy.genfromtxt(file_y, delimiter=' ')
    print("Split the data into training/testing sets \n")
    
    # Split the data into training/testing sets
    X_train, X_test, y_train, y_test_0 = train_test_split(X, y, test_size=0.33, random_state=42)
     
    
    print("Feature Scaling \n")
    
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    print("Applying PCA to select features \n")
    
    # PCA to select features
    pca = PCA(n_components=20, svd_solver='full')
    pca.fit(X)
    X = pca.transform(X)
    #explained_variance=pca.explained_variance_ratio_
    
    print("Applying SVM classifier \n")
    # SVM Classifier
    clf = SVC()
    clf.fit(X_train, y_train)
    y_predict_0 = clf.predict(X_test)
    cm = confusion_matrix(y_test_0, y_predict_0)
    print(cm)
    print("Accuracy score of Liking SVM-PCA")
    print(accuracy_score(y_test_0, y_predict_0)*100)
    
   
if __name__ == '__main__':
    svm_classifier_pca()
# Out:
# LABEL 0 - Valence
#
# Split the data into training/testing sets
#
# Feature Scaling
#
# Applying PCA to select features
#
# Applying SVM classifier
#
# [[  0 152]
#  [  0 271]]
# Accuracy score of Valence SVM-PCA
# 64.0661938534279
# LABEL 1 - Arousal
#
# Split the data into training/testing sets
#
# Feature Scaling
#
# Applying PCA to select features
#
# Applying SVM classifier
#
# [[  3 149]
#  [  2 269]]
# Accuracy score of Arousal SVM-PCA
# 64.30260047281324
# LABEL 2 - Dominance
#
# Split the data into training/testing sets
#
# Feature Scaling
#
# Applying PCA to select features
#
# Applying SVM classifier
#
# [[  3 149]
#  [  2 269]]
# Accuracy score of Dominance SVM-PCA
# 64.30260047281324
# LABEL 3 - Liking
#
# Split the data into training/testing sets
#
# Feature Scaling
#
# Applying PCA to select features
#
# Applying SVM classifier
#
# [[  1 134]
#  [  0 288]]
# Accuracy score of Liking SVM-PCA
# 68.32151300236407
